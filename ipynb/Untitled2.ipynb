# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyqtgraph as pg
import matplotlib
# %matplotlib inline
matplotlib.set('Qt4Agg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-bf380343683c> in <module>()
#       6 import matplotlib
#       7 get_ipython().magic('matplotlib inline')
# ----> 8 matplotlib.set('Qt4Agg')
#
# AttributeError: module 'matplotlib' has no attribute 'set'

# %%
fname="/Users/jins/Downloads/28A183056A08_20160106091153.csv"
df = pd.read_csv(fname,skiprows=5,parse_dates=[2])
d=np.array(df)

# %%
df.columns
# Out:
# Index(['//ARTIFACT', 'NUM', 'DATE', 'ACC_X', 'ACC_Y', 'ACC_Z', 'GYRO_X',
#        'GYRO_Y', 'GYRO_Z', 'EOG_L', 'EOG_R', 'EOG_H', 'EOG_V'],
#       dtype='object')

# %%
step=np.arange(-10000,10000,2000)
plt.hist(d[:,3],bins=step)
#pd.value_counts(d[:,3],a[2])
# Out:
# (array([    0.,     0.,     0.,    28.,  4558.,  3419.,    15.,     0.,
#             0.]),
#  array([-10000,  -8000,  -6000,  -4000,  -2000,      0,   2000,   4000,
#           6000,   8000]),
#  <a list of 9 Patch objects>)

# %%
df
# Out:
#       //ARTIFACT   NUM                    DATE  ACC_X  ACC_Y  ACC_Z  GYRO_X  \
# 0            0.0     1 2016-01-06 09:11:53.410    113   1358  -3872     200
# 1            0.0     2 2016-01-06 09:11:53.420     44   1232  -3954     281
# 2            0.0     3 2016-01-06 09:11:53.430     20   1125  -3925     354
# 3            0.0     4 2016-01-06 09:11:53.440      9   1093  -3903     393
# 4            0.0     5 2016-01-06 09:11:53.450      5   1046  -3884     414
# 5            0.0     6 2016-01-06 09:11:53.460     -9    968  -3891     421
# 6            0.0     7 2016-01-06 09:11:53.470    -55    883  -3866     404
# 7            0.0     8 2016-01-06 09:11:53.480    -70    815  -3893     383
# 8            0.0     9 2016-01-06 09:11:53.490    -76    736  -3860     357
# 9            0.0    10 2016-01-06 09:11:53.500   -112    645  -3894     328
# 10           0.0    11 2016-01-06 09:11:53.510   -138    534  -3878     301
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8020, step=1)

# %%
df['//ARTIFACT'].fillna(0,inplace=True)
